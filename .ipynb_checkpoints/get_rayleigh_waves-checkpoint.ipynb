# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
from obspy.core.utcdatetime import UTCDateTime
import importlib
import matplotlib.pyplot as plt
import os

import obspy
from obspy.clients.fdsn import Client

# %% [markdown]
# ## US data + Alaskan quakes

# %%
c_event = Client("USGS")

## Region
starttime = UTCDateTime("2016-01-01")
endtime = UTCDateTime("2023-01-01")
minmagnitude = 6.
maxdepth = 50
region = dict(minlatitude=52, maxlatitude=73, minlongitude=-170, maxlongitude=-130) # Alaska

# Get the event information. The temporal and magnitude constraints make it unique
events = c_event.get_events(starttime=starttime, endtime=endtime, minmagnitude=minmagnitude, maxdepth=maxdepth, orderby='magnitude', **region)
print(events)
# Out:
# 19 Event(s) in Catalog:
# 2021-07-29T06:15:49.188000Z | +55.364, -157.888 | 8.2  mww | manual
# 2018-01-23T09:31:40.890000Z | +56.004, -149.166 | 7.9  mww | manual
# ...
# 2018-08-12T21:15:00.999000Z | +69.523, -144.339 | 6.0  mw | manual
# 2018-12-31T02:35:37.670000Z | +54.427, -161.513 | 6.0  mww | manual
# To see all events call 'print(CatalogObject.__str__(print_all=True))'

# %%
inv = Client('IRIS').get_stations(network="TA", station="*", channel="BDF", starttime=UTCDateTime('2018-01-01'), endtime=UTCDateTime('2018-01-01') + 3600, level="response")
inv.select(**region)

# %%
print(inv.select(**region, starttime=starttime))
# Out:
# Inventory created at 2023-05-11T11:38:18.152500Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.52
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2018-01-01...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (1):
# 			TA
# 		Stations (192):
# 			TA.A19K (Wainwright, AK, USA)
# 			TA.A21K (Barrow, AK, USA)
# 			TA.A22K (Sinclair Lake, AK, USA)
# 			TA.B18K (Kokolik River, AK, USA)
# 			TA.B20K (Meade River, AK, USA)
# 			TA.B21K (Ikpikpuk River, AK, USA)
# 			TA.B22K (Teshekpuk Lake, AK, USA)
# 			TA.C16K (Lisburne Hills, AK, USA)
# 			TA.C17K (DeLong Mountains, AK, USA)
# 			TA.C18K (Utukok River, AK, USA)
# 			TA.C19K (Lookout Ridge, AK, USA)
# 			TA.C21K (Knifeblade Ridge, AK, USA)
# 			TA.C23K (Itkillik River, AK, USA)
# 			TA.C24K (Franklin Bluffs, AK, USA)
# 			TA.C26K (Camden Bay, AK, USA)
# 			TA.C27K (Jago River, AK, USA)
# 			TA.D17K (Noatak River, AK, USA)
# 			TA.D19K (Kuna River, AK, USA)
# 			TA.D20K (Etivluk River, AK, USA)
# 			TA.D22K (Ayikyak River, AK, USA)
# 			TA.D23K (Nanushuk River, AK USA)
# 			TA.D24K (Happy Valley, AK, USA)
# 			TA.D25K (Kavik River, AK, USA)
# 			TA.D27M (Malcolm River, YT, CAN)
# 			TA.D28M (Stokes Point, YT, CAN)
# 			TA.E17K (Hotham Inlet, AK, USA)
# 			TA.E18K (Tukpahlearik Creek, AK, USA)
# 			TA.E19K (Redstone River, AK, USA)
# 			TA.O17K (Koliganek, Bristol Bay, AK, USA)
# 			TA.O18K (Koktuh Hills, AK, USA)
# 			TA.O19K (Port Alsworth, AK, USA)
# 			TA.O20K (Slope Mountain, AK, USA)
# 			TA.O22K (Cooper Landing, AK, USA)
# 			TA.O28M (Mount Upton, YT, CAN)
# 			TA.O29M (Mount Kennedy, YT, CAN)
# 			TA.O30N (Mendenhall, YT, Canada)
# 			TA.P08K (Saint George Island, AK, USA)
# 			TA.P16K (Nushagak River, AK, USA)
# 			TA.P17K (Kvichak River, AK, USA)
# 			TA.P18K (Big Mountain, AK, USA)
# 			TA.P19K (Oil Pt, AK, USA)
# 			TA.P23K (Montague Island, AK, USA)
# 			TA.P29M (Windy Craggy, BC, CAN)
# 			TA.P30M (Million Dollar Falls, (MDFC Geodetic GPS), YT, CA)
# 			TA.P32M (Atlin, BC, CAN)
# 			TA.P33M (Teslin, Yukon, CA)
# 			TA.POKR (Poker Flat Research Range, AK, USA)
# 			TA.Q16K (King Salmon, AK, USA)
# 			TA.Q17K (Contact Creek, Katmai, AK, USA)
# 			TA.Q18K (Katmai Hardscrabble Creek, AK, USA)
# 			TA.Q19K (Cape Douglas, AK, USA)
# 			TA.Q20K (Shuyak Island, AK, USA)
# 			TA.Q23K (Middleton Island, AK, USA)
# 			TA.Q32M (Nakina River, BC, CAN)
# 			TA.R16K (Pilot Point, AK, USA)
# 			TA.R17K (Ugashik Creek, AK, USA)
# 			TA.R18K (Karluk, AK, USA)
# 			TA.R31K (City Hall, Gustavus, AK, USA)
# 			TA.R32K (Eaglecrest, AK, USA)
# 			TA.R33M (Jennings River, BC, CAN)
# 			TA.S12K (Black Hills, AK, USA)
# 			TA.S14K (Fog Glacier, AK, USA)
# 			TA.S31K (Pelican, AK, USA)
# 			TA.S32K (Killisnoo, AK, USA)
# 			TA.S34M (Telegraph Creek, BC, CAN)
# 			TA.T33K (Petersburg, AK, USA)
# 			TA.T35M (Bob Quinn, BC, CAN)
# 			TA.TCOL (CIGO, UAF Yankovich Road, Fairbanks, AK, USA)
# 			TA.TOLK (Toolik Lake Research Station, AK, USA)
# 			TA.U33K (Whale Pass, AK, USA)
# 			TA.U35K (Hyder, AK, USA)
# 			TA.V35K (Ketchikan, AK, USA)
# 		Channels (383):
# 			TA.A19K.20.BDF, TA.A19K.EP.BDF, TA.A21K.20.BDF, TA.A21K.EP.BDF,
# 			TA.A22K.20.BDF, TA.A22K.EP.BDF, TA.B18K.20.BDF, TA.B18K.EP.BDF,
# 			TA.B20K.20.BDF, TA.B20K.EP.BDF, TA.B21K.20.BDF, TA.B21K.EP.BDF,
# 			TA.B22K.20.BDF, TA.B22K.EP.BDF, TA.C16K.20.BDF, TA.C16K.EP.BDF,
# 			TA.C17K.20.BDF, TA.C17K.EP.BDF, TA.C18K.20.BDF, TA.C18K.EP.BDF,
# 			TA.C19K.20.BDF, TA.C19K.EP.BDF, TA.C21K.20.BDF, TA.C21K.EP.BDF,
# 			TA.C23K.20.BDF, TA.C23K.EP.BDF, TA.C24K.20.BDF, TA.C24K.EP.BDF,
# 			TA.C26K.20.BDF, TA.C26K.EP.BDF, TA.C27K.20.BDF, TA.C27K.EP.BDF,
# 			TA.D17K.20.BDF, TA.D17K.EP.BDF, TA.D19K.20.BDF, TA.D19K.EP.BDF,
# 			TA.D20K.20.BDF, TA.D20K.EP.BDF, TA.D22K.20.BDF, TA.D22K.EP.BDF,
# 			TA.D23K.20.BDF, TA.D23K.EP.BDF, TA.D24K.20.BDF, TA.D24K.EP.BDF,
# 			TA.D25K.20.BDF, TA.D25K.EP.BDF, TA.D27M.20.BDF, TA.D27M.EP.BDF,
# 			TA.D28M.20.BDF, TA.D28M.EP.BDF, TA.E17K.20.BDF, TA.E17K.EP.BDF,
# 			TA.E18K.20.BDF, TA.E18K.EP.BDF, TA.E19K.20.BDF, TA.E19K.EP.BDF,
# 			TA.E20K.20.BDF, TA.E20K.EP.BDF, TA.E21K.20.BDF, TA.E21K.EP.BDF,
# 			TA.E22K.20.BDF, TA.E22K.EP.BDF, TA.E23K.20.BDF, TA.E23K.EP.BDF,
# 			TA.E24K.20.BDF, TA.E24K.EP.BDF, TA.E25K.20.BDF, TA.E25K.EP.BDF,
# 			TA.E27K.20.BDF, TA.E27K.EP.BDF, TA.E28M.20.BDF, TA.E28M.EP.BDF,
# 			TA.E29M.20.BDF, TA.E29M.EP.BDF, TA.EPYK.20.BDF, TA.EPYK.EP.BDF,
# 			TA.F14K.20.BDF, TA.F14K.EP.BDF, TA.F15K.20.BDF, TA.F15K.EP.BDF,
# 			TA.F17K.20.BDF, TA.F17K.EP.BDF, TA.F18K.20.BDF, TA.F18K.EP.BDF,
# 			TA.F19K.20.BDF, TA.F19K.EP.BDF, TA.F20K.20.BDF, TA.F20K.EP.BDF,
# 			TA.F21K.20.BDF, TA.F21K.EP.BDF, TA.F22K.20.BDF, TA.F22K.EP.BDF,
# 			TA.F24K.20.BDF, TA.F24K.EP.BDF, TA.F25K.20.BDF, TA.F25K.EP.BDF,
# 			TA.F26K.20.BDF, TA.F26K.EP.BDF, TA.F28M.20.BDF, TA.F28M.EP.BDF,
# 			TA.F30M.20.BDF, TA.F30M.EP.BDF, TA.F31M.20.BDF, TA.F31M.EP.BDF,
# 			TA.G15K.20.BDF, TA.G15K.EP.BDF, TA.G16K.20.BDF, TA.G16K.EP.BDF,
# 			TA.G17K.20.BDF, TA.G17K.EP.BDF, TA.G18K.20.BDF, TA.G18K.EP.BDF,
# 			TA.G19K.20.BDF, TA.G19K.EP.BDF, TA.G21K.20.BDF, TA.G21K.EP.BDF,
# 			TA.G22K.20.BDF, TA.G22K.EP.BDF, TA.G23K.20.BDF, TA.G23K.EP.BDF,
# 			TA.G24K.20.BDF, TA.G24K.EP.BDF, TA.G25K.20.BDF, TA.G25K.EP.BDF,
# 			TA.G26K.20.BDF, TA.G26K.EP.BDF, TA.G27K.20.BDF, TA.G27K.EP.BDF,
# 			TA.G29M.20.BDF, TA.G29M.EP.BDF, TA.G30M.20.BDF, TA.G30M.EP.BDF,
# 			TA.G31M.20.BDF, TA.G31M.EP.BDF, TA.H16K.20.BDF, TA.H16K.EP.BDF,
# 			TA.H17K.20.BDF, TA.H17K.EP.BDF, TA.H18K.20.BDF, TA.H18K.EP.BDF,
# 			TA.H19K.20.BDF, TA.H19K.EP.BDF, TA.H20K.20.BDF, TA.H20K.EP.BDF,
# 			TA.H21K.20.BDF, TA.H21K.EP.BDF, TA.H22K.20.BDF, TA.H22K.EP.BDF,
# 			TA.H23K.20.BDF, TA.H23K.EP.BDF, TA.H24K.20.BDF, TA.H24K.EP.BDF,
# 			TA.H25L.20.BDF, TA.H25L.EP.BDF, TA.H27K.20.BDF, TA.H27K.EP.BDF,
# 			TA.H29M.20.BDF, TA.H29M.EP.BDF, TA.H31M.20.BDF, TA.H31M.EP.BDF,
# 			TA.HARP.20.BDF, TA.HARP.EP.BDF, TA.I17K.20.BDF, TA.I17K.EP.BDF,
# 			TA.I20K.20.BDF, TA.I20K.EP.BDF, TA.I21K.20.BDF, TA.I21K.EP.BDF,
# 			TA.I23K.20.BDF, TA.I23K.EP.BDF, TA.I26K.20.BDF, TA.I26K.EP.BDF,
# 			TA.I27K.20.BDF, TA.I27K.EP.BDF, TA.I28M.20.BDF, TA.I28M.EP.BDF,
# 			TA.I29M.20.BDF, TA.I29M.EP.BDF, TA.I30M.20.BDF, TA.I30M.EP.BDF,
# 			TA.J14K.20.BDF, TA.J14K.EP.BDF, TA.J16K.20.BDF, TA.J16K.EP.BDF,
# 			TA.J17K.20.BDF, TA.J17K.EP.BDF, TA.J18K.20.BDF, TA.J18K.EP.BDF,
# 			TA.J19K.20.BDF, TA.J19K.EP.BDF, TA.J20K.20.BDF, TA.J20K.EP.BDF,
# 			TA.J25K.20.BDF, TA.J25K.EP.BDF, TA.J26L.20.BDF, TA.J26L.EP.BDF,
# 			TA.J29N.20.BDF, TA.J29N.EP.BDF, TA.J30M.20.BDF, TA.J30M.EP.BDF,
# 			TA.K13K.20.BDF, TA.K13K.EP.BDF, TA.K15K.20.BDF, TA.K15K.EP.BDF,
# 			TA.K17K.20.BDF, TA.K17K.EP.BDF, TA.K20K.20.BDF, TA.K20K.EP.BDF,
# 			TA.K24K.20.BDF, TA.K24K.EP.BDF, TA.K27K.20.BDF, TA.K27K.EP.BDF,
# 			TA.K29M.20.BDF, TA.K29M.EP.BDF, TA.L14K.20.BDF, TA.L14K.EP.BDF,
# 			TA.L15K.20.BDF, TA.L16K.20.BDF, TA.L16K.EP.BDF, TA.L17K.20.BDF,
# 			TA.L17K.EP.BDF, TA.L18K.20.BDF, TA.L18K.EP.BDF, TA.L19K.20.BDF,
# 			TA.L19K.EP.BDF, TA.L20K.20.BDF, TA.L20K.EP.BDF, TA.L26K.20.BDF,
# 			TA.L26K.EP.BDF, TA.L27K.20.BDF, TA.L27K.EP.BDF, TA.L29M.20.BDF,
# 			TA.Q17K.EP.BDF, TA.Q18K.20.BDF, TA.Q18K.EP.BDF, TA.Q19K.20.BDF,
# 			TA.Q19K.EP.BDF, TA.Q20K.20.BDF, TA.Q20K.EP.BDF, TA.Q23K.20.BDF,
# 			TA.Q23K.EP.BDF, TA.Q32M.20.BDF, TA.Q32M.EP.BDF, TA.R16K.20.BDF,
# 			TA.R16K.EP.BDF, TA.R17K.20.BDF, TA.R17K.EP.BDF, TA.R18K.20.BDF,
# 			TA.R18K.EP.BDF, TA.R31K.20.BDF, TA.R31K.EP.BDF, TA.R32K.20.BDF,
# 			TA.R32K.EP.BDF, TA.R33M.20.BDF, TA.R33M.EP.BDF, TA.S12K.20.BDF,
# 			TA.S12K.EP.BDF, TA.S14K.20.BDF, TA.S14K.EP.BDF, TA.S31K.20.BDF,
# 			TA.S31K.EP.BDF, TA.S32K.20.BDF, TA.S32K.EP.BDF, TA.S34M.20.BDF,
# 			TA.S34M.EP.BDF, TA.T33K.20.BDF, TA.T33K.EP.BDF, TA.T35M.20.BDF,
# 			TA.T35M.EP.BDF, TA.TCOL.20.BDF, TA.TCOL.EP.BDF, TA.TOLK.20.BDF,
# 			TA.TOLK.EP.BDF, TA.U33K.20.BDF, TA.U33K.EP.BDF, TA.U35K.20.BDF,
# 			TA.U35K.EP.BDF, TA.V35K.20.BDF, TA.V35K.EP.BDF

# %%
from pyproj import Geod

wgs84_geod = Geod(ellps='WGS84')
client = Client("IRIS")
vel_min = 2.5
vel_max = 7.

#inv = client.get_stations(network="TA", station="*", channel="BDF", starttime=starttime, endtime=endtime, level="response")

for event in events[3:]:
    
    source_loc = (event.origins[0].latitude, event.origins[0].longitude)
    origin_time = event.origins[0].time
    inv_loc = inv.select(**region, starttime=origin_time, endtime=origin_time+2000.)
    station_loc = (inv_loc[0][0].latitude, inv_loc[0][0].longitude)
    stations = [stat.code for stat in inv_loc[0]]
    #print(station_loc)
    #print(stations)
    #break
    _, _, range_km = wgs84_geod.inv(source_loc[1], source_loc[0], station_loc[1], station_loc[0])
    range_km /= 1e3
    tmin = range_km/vel_max
    tmax = range_km/vel_min
    
    print(event.origins[0])
    print(f'- Distance to {array}: {range_km} km')
    print(f'- Waveform duration: {tmax-tmin} s')

    #st = client.get_waveforms(stations, component, origin_time+tmin, origin_time+tmax)
    st = client.get_waveforms(network="TA", station="*", channel="BDF", starttime=event_time - 60, endtime=event_time + 3600)
    print(st)
    if len(st) == 0:
        print('No data')
        continue
    
    
    #for tr in st:
    #    tr.stats.network = 'NO'
    #    tr.stats.calib = 1.
    #st.remove_response(inv)
    st.detrend()
    st.filter('bandpass', freqmin=0.01, freqmax=2.5, zerophase=True)
    break
# Out:
# Origin
# 	        resource_id: ResourceIdentifier(id="quakeml:earthquake.usgs.gov/product/origin/us6000c9hg/us/1609283264040/product.xml")
# 	               time: UTCDateTime(2020, 10, 19, 20, 54, 38, 950000)
# 	          longitude: -159.6258
# 	           latitude: 54.602
# 	              depth: 28370.0 [uncertainty=3000.0]
# 	            quality: OriginQuality(used_phase_count=200, standard_error=0.91, azimuthal_gap=36.0, minimum_distance=0.23)
# 	 origin_uncertainty: OriginUncertainty(horizontal_uncertainty=5100.0, preferred_description='horizontal uncertainty')
# 	    evaluation_mode: 'manual'
# 	      creation_info: CreationInfo(agency_id='us', creation_time=UTCDateTime(2020, 12, 29, 23, 7, 44, 40000))
# - Distance to NORES: 1771.9669407640854 km
# - Waveform duration: 455.6486419107648 s
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-232-08cefe0e2061> in <module>
#      28
#      29     #st = client.get_waveforms(stations, component, origin_time+tmin, origin_time+tmax)
# ---> 30     st = client.get_waveforms(network="TA", station="*", channel="BDF", starttime=event_time - 60, endtime=event_time + 3600)
#      31     print(st)
#      32     if len(st) == 0:
#
# NameError: name 'event_time' is not defined

# %% [markdown]
# ## Norwegian data + Eurasian quakes

# %%
c_event = Client("USGS")

## Region
starttime = UTCDateTime("2016-01-01")
endtime = UTCDateTime("2023-01-01")
minmagnitude = 6.5
maxdepth = 50
region = dict(minlatitude=10, maxlatitude=81, minlongitude=9, maxlongitude=169) # Eurasia

# Get the event information. The temporal and magnitude constraints make it unique
events = c_event.get_events(starttime=starttime, endtime=endtime, minmagnitude=minmagnitude, maxdepth=maxdepth, orderby='magnitude', **region)

# %%
print(events)
# Out:
# 34 Event(s) in Catalog:
# 2017-07-17T23:34:13.740000Z | +54.443, +168.857 | 7.7  mww | manual
# 2022-03-16T14:36:30.997000Z | +37.713, +141.579 | 7.3  mww | manual
# ...
# 2020-05-02T12:51:05.561000Z | +34.182,  +25.710 | 6.5  mww | manual
# 2017-08-08T13:19:49.540000Z | +33.193, +103.855 | 6.5  mww | manual
# To see all events call 'print(CatalogObject.__str__(print_all=True))'

# %%
from obspy import read_inventory
array, stations, component = 'I37NO', 'I37H*', 'BDF,HHZ'
array, stations, component = 'NORES', 'NRA0', 'BDF,HHZ'
#inv = read_inventory('/db/inventory/SEED/{}/*.SEED'.format(array))
inv = read_inventory(f'./invs/{array}.xml')
station_loc = (inv[0][0].latitude, inv[0][0].longitude)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-20535276c4b2> in <module>
#       3 array, stations, component = 'NORES', 'NRA0', 'BDF,HHZ'
#       4 #inv = read_inventory('/db/inventory/SEED/{}/*.SEED'.format(array))
# ----> 5 inv = read_inventory(f'./invs/{array}.xml')
#       6 station_loc = (inv[0][0].latitude, inv[0][0].longitude)
#
# <decorator-gen-165> in read_inventory(path_or_file_object, format, level, *args, **kwargs)
#
# ~/miniconda2/envs/seismonpy/lib/python3.7/site-packages/obspy/core/util/decorator.py in _map_example_filename(func, *args, **kwargs)
#     289                         except IOError:
#     290                             pass
# --> 291         return func(*args, **kwargs)
#     292     return _map_example_filename
#     293
#
# ~/miniconda2/envs/seismonpy/lib/python3.7/site-packages/obspy/core/inventory/inventory.py in read_inventory(path_or_file_object, format, level, *args, **kwargs)
#      90     else:
#      91         return _generic_reader(path_or_file_object, _read, format=format,
# ---> 92                                **kwargs)
#      93
#      94
#
# ~/miniconda2/envs/seismonpy/lib/python3.7/site-packages/obspy/core/util/base.py in _generic_reader(pathname_or_url, callback_func, **kwargs)
#     653                 raise Exception("No file matching file pattern: %s" % pathname)
#     654             elif not glob.has_magic(pathname) and not Path(pathname).is_file():
# --> 655                 raise IOError(2, "No such file or directory", pathname)
#     656
#     657         generic = callback_func(pathnames[0], **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './invs/NORES.xml'

# %%
from pyproj import Geod
from seismonpy.norsardb import Client as Client_NORSAR

wgs84_geod = Geod(ellps='WGS84')
client = Client_NORSAR()
vel_min = 2.5
vel_max = 7.

for event in events[3:]:
    
    source_loc = (event.origins[0].latitude, event.origins[0].longitude)
    _, _, range_km = wgs84_geod.inv(source_loc[1], source_loc[0], station_loc[1], station_loc[0])
    range_km /= 1e3
    origin_time = event.origins[0].time
    tmin = range_km/vel_max
    tmax = range_km/vel_min
    
    print(event.origins[0])
    print(f'- Distance to {array}: {range_km} km')
    print(f'- Waveform duration: {tmax-tmin} s')

    st = client.get_waveforms(stations, component, origin_time+tmin, origin_time+tmax)
    print(st)
    if len(st) == 0:
        print('No data')
        continue
    
    
    for tr in st:
        tr.stats.network = 'NO'
        tr.stats.calib = 1.
    st.remove_response(inv)
    st.detrend()
    st.filter('bandpass', freqmin=0.01, freqmax=2.5, zerophase=True)
    break
# Out:
# Origin
# 	        resource_id: ResourceIdentifier(id="quakeml:earthquake.usgs.gov/product/origin/us2000bmcg/us/1517885130040/product.xml")
# 	               time: UTCDateTime(2017, 11, 12, 18, 18, 17, 180000)
# 	          longitude: 45.9592
# 	           latitude: 34.9109
# 	              depth: 19000.0 [uncertainty=1700.0]
# 	            quality: OriginQuality(used_phase_count=148, standard_error=1.29, azimuthal_gap=33.0, minimum_distance=0.284)
# 	 origin_uncertainty: OriginUncertainty(horizontal_uncertainty=4900.0, preferred_description='horizontal uncertainty')
# 	    evaluation_mode: 'manual'
# 	      creation_info: CreationInfo(agency_id='us', creation_time=UTCDateTime(2018, 2, 6, 2, 45, 30, 40000))
# - Distance to NORES: 3774.549658619137 km
# - Waveform duration: 970.598483644921 s
# 2 Trace(s) in Stream:
# .NRA0..BDF | 2017-11-12T18:27:16.412500Z - 2017-11-12T18:43:26.987500Z | 80.0 Hz, 77647 samples
# .NRA0..HHZ | 2017-11-12T18:27:16.412500Z - 2017-11-12T18:43:26.987500Z | 80.0 Hz, 77647 samples

# %%
from scipy import signal

st_c = st.copy()
st_c.filter('bandpass', freqmin=0.03, freqmax=0.25)
#st_c.filter('highpass', freq=0.02)
#st_c.select(station='NRA2').plot(equal_scale=False)
plt.figure()
for tr in st_c:
    tr.resample(20.)
    plt.plot(tr.times(), tr.data/tr.data.max(), label=tr.stats.channel)
#corr = signal.correlate(st_c[0].data/st_c[0].data.max(), st_c[1].data/st_c[1].data.max(), mode='same')
corr = np.correlate(a=st_c[0].data/st_c[0].data.max(), v=st_c[1].data/st_c[1].data.max())
#plt.plot(tr.times(), corr/corr.max())
plt.title(corr)
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="862.9630239248646">
# /staff/quentin/miniconda2/envs/seismonpy/lib/python3.7/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
